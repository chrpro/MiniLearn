# %%
import numpy as np

# %%
def generate_train_header(x, y, name):
    '''
    this method generate the
    :param x:  input x data size
    :param y:  input label (one hot label)
    :return:
    '''
    # quantize input x
    min_value = np.min(x)
    max_value = np.max(x)

    int_bits = int(np.ceil(np.log2(max(abs(min_value), abs(max_value)))))
    dec_bits = 7 - int_bits
    x = np.round(x*2**dec_bits).astype(np.int8)
    
#     print(x[0][0])
    data = x.astype(dtype="byte")
    label = y
    node = 0
    file=name
    with open(file, 'w') as f:
        num_of_image = x.shape[0]
        for i in range(num_of_image):
            f.write('#define NODE_%d_TRAIN_IMG_%d {'%(node,i) )
#             print(data[i])
            (data[i]).flatten().tofile(f, sep=", ") # convert 0~1 to 0~127
            f.write('} \n')
            f.write('#define NODE_%d_TRAIN_IMG%d_LABEL'% (node, i))
            f.write(' %d \n \n' % label[i])
        f.write('#define NODE_%d_TOTAL_TRAIN_IMAGES %d \n \n'%(node,num_of_image))

        f.write('static q7_t NODE_%d_TRAIN_IMAGES[%d][%d] = {' % (node,num_of_image, data[0].flatten().shape[0]))
        f.write('NODE_%d_TRAIN_IMG_0'%(node))
        for i in range(num_of_image -1):
            f.write(',NODE_%d_TRAIN_IMG_%d'%(node, i+1))
        f.write('};\n\n')

        f.write('static q7_t NODE_%d_TRAIN_LABELS[%d] = {' % (node,num_of_image))
        f.write('NODE_%d_TRAIN_IMG0_LABEL'%(node))
        for i in range(num_of_image -1):
            f.write(',NODE_%d_TRAIN_IMG%d_LABEL'%(node, i+1))
        f.write('};\n\n')

#     return 000

# %%
def generate_test_bin(x, y, file='test_data.h'):
    '''
    method to generate the test data as a header file
    :param x:  input x data size
    :param y:  input label 
    :write to file 
    :return: nothing
    '''
    # quantize input x
    min_value = np.min(x)
    max_value = np.max(x)

    int_bits = int(np.ceil(np.log2(max(abs(min_value), abs(max_value)))))
    dec_bits = 7 - int_bits
    x = np.round(x*2**dec_bits).astype(np.int8)
    
    data = x
    label = y

    with open(file, 'w') as f:
        num_of_image = x.shape[0]
        print("Number of test images:",num_of_image)
        for i in range(num_of_image):
            f.write('#define TEST_IMG%d {'% (i))
            data[i].flatten().tofile(f, sep=", ")
            f.write('} \n')
            f.write('#define TEST_IMG%d_LABEL'% (i))
            f.write(' %d \n \n' % label[i])
        f.write('#define TOTAL_TEST_IMAGES %d \n \n'%(num_of_image))

        f.write('static q7_t TEST_IMAGES[%d][%d] = {' % (num_of_image, data[0].flatten().shape[0]))
        f.write('TEST_IMG0')
        for i in range(num_of_image -1):
            f.write(',TEST_IMG%d'%(i+1))
        f.write('};\n\n')

        f.write('static q7_t TEST_LABELS[%d] = {' % (num_of_image))
        f.write('TEST_IMG0_LABEL')
        for i in range(num_of_image -1):
            f.write(',TEST_IMG%d_LABEL'%(i+1))
        f.write('};\n\n')

# %%
def federated_train_images(node, data, label, size, file='renameTHIS.h'):
    # test
    with open(file, 'w') as f:
        num_of_image = size
        for i in range(num_of_image):
            f.write('#define NODE_%d_TRAIN_IMG_%d {'%(node,i) )
            np.round(data[i]).flatten().tofile(f, sep=", ", format="%d") # convert 0~1 to 0~127
            f.write('} \n')
            f.write('#define NODE_%d_TRAIN_IMG%d_LABEL'% (node, i))
            f.write(' %d \n \n' % label[i])
        f.write('#define NODE_%d_TOTAL_TRAIN_IMAGES %d \n \n'%(node,num_of_image))

        f.write('static q7_t NODE_%d_TRAIN_IMAGES[%d][%d] = {' % (node,num_of_image, data[0].flatten().shape[0]))
        f.write('NODE_%d_TRAIN_IMG_0'%(node))
        for i in range(num_of_image -1):
            f.write(',NODE_%d_TRAIN_IMG_%d'%(node, i+1))
        f.write('};\n\n')

        f.write('static q7_t NODE_%d_TRAIN_LABELS[%d] = {' % (node,num_of_image))
        f.write('NODE_%d_TRAIN_IMG0_LABEL'%(node))
        for i in range(num_of_image -1):
            f.write(',NODE_%d_TRAIN_IMG%d_LABEL'%(node, i+1))
        f.write('};\n\n')

# %%
import os
nnscript = os.path.abspath('../../scripts')
os.sys.path.append(nnscript)

# %%
import pandas as pd

# %%
# load data
try:
    x_train = np.load('train_data.npy')
    y_train = np.load('train_label.npy')
    x_test = np.load('test_data.npy')
    y_test = np.load('test_label.npy')
    x_val = np.load('val_data.npy')
    y_val = np.load('val_label.npy')
except:
    (x_train, y_train), (x_test, y_test), (x_val, y_val) = merge_mfcc_file()
    np.save('train_data.npy', x_train)
    np.save('train_label.npy', y_train)
    np.save('test_data.npy', x_test)
    np.save('test_label.npy', y_test)
    np.save('val_data.npy', x_val)
    np.save('val_label.npy', y_val)

# %%
selected_lable = ['backward', 'bed', 'bird', 'cat', 'dog', 'down', 'eight','five', 'follow', 'forward',
                      'four','go','happy','house','learn','left','marvin','nine','no','off','on','one','right',
                      'seven','sheila','six','stop','three','tree','two','up','visual','yes','zero']

# %%
# only take 2~13 coefficient. 1 is destructive.
x_train = x_train[:, :, 1:]
x_test = x_test[:, :, 1:]
x_val = x_val[:, :, 1:]

# expand on channel axis because we only have one channel
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], x_train.shape[2], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], x_test.shape[2], 1))
x_val = x_val.reshape((x_val.shape[0], x_val.shape[1], x_val.shape[2], 1))
print('x_train shape:', x_train.shape, 'max', x_train.max(), 'min', x_train.min())

# training data enforcement
x_train = np.vstack((x_train, x_train*0.8))
y_train = np.hstack((y_train, y_train))
print(y_train.shape)

def normalize(data, n, quantize=True):
    limit = pow(2, n)
    data = np.clip(data, -limit, limit) / limit
    if quantize:
        data = np.round(data * 128) / 128.0
    return data

# instead of using maximum value for quantised, we allows some saturation to save more details in small values.
x_train = normalize(x_train, 3)
x_test = normalize(x_test, 3)
x_val = normalize(x_val, 3)


# shuffle test data
permutation = np.random.permutation(x_test.shape[0])
x_test = x_test[permutation, :]
y_test = y_test[permutation]

permutation = np.random.permutation(x_train.shape[0])
x_train = x_train[permutation, :]
y_train = y_train[permutation]

permutation = np.random.permutation(x_val.shape[0])
x_val = x_val[permutation, :]
y_val = y_val[permutation]
# Out:
# x_train shape: (85245, 62, 12, 1) max 23.778687 min -37.92257
# (170490,)

# %%
y_train, _ = pd.factorize( y_train) 
y_test, _ = pd.factorize( y_test) 
y_val, _ = pd.factorize( y_val)

# %%
sumples = 500


for i in range (30):
    labelindices = np.random.choice(34, 5, replace=False)
    print(labelindices)
    sub_x_test = x_test[np.isin(y_test.flatten(), labelindices).flatten()]
    sub_y_test = y_test[np.isin(y_test.flatten(),labelindices).flatten()] 

    sub_y_test = np.unique(sub_y_test, return_inverse=True)[1] 
    # print(sub_y_test)
    unique, counts = np.unique(sub_y_test[sumples:], return_counts=True)
    print(dict(zip(unique, counts)) )

    unique, counts = np.unique(sub_y_test[:sumples], return_counts=True)
    print(dict(zip(unique, counts)) )




    generate_train_header(sub_x_test[:sumples], sub_y_test[:sumples], name='fed_prunningNNOM-keyspot/src/keyspot_train_data.h')
    generate_test_bin(sub_x_test[sumples:], sub_y_test[sumples:], file='fed_prunningNNOM-keyspot/src/keyspot_test.h')
    # !make -C ./fed_prunningNNOM-keyspot/ 
    # !./fed_prunningNNOM-keyspot/uwnet
# Out:
# [17  0  5 16 10]
# {0: 161, 1: 299, 2: 315, 3: 307, 4: 115}
# {0: 51, 1: 107, 2: 93, 3: 99, 4: 50}
# Number of test images: 1197
# make: Entering directory '/Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/examples/keyword_spotting/fed_prunningNNOM-keyspot'
# OBJECTS are main.o image.o args.o matrix.o list.o data.o classifier.o net.o convolutional_layer.o connected_layer.o activations.o activation_layer.o arm_fully_connected_q7_opt.o arm_convolve_HWC_q7_basic.o arm_convolve_HWC_q7_fast.o arm_relu_q7.o arm_pool_q7_HWC.o arm_convolve_HWC_q7_RGB.o arm_softmax_q7.o arm_max_q7.o arm_add_q7.o arm_convolve_1x1_HWC_q7_fast_nonsquare.o arm_convolve_HWC_q15_fast.o arm_convolve_HWC_q15_fast_nonsquare.o arm_convolve_HWC_q7_basic_nonsquare.o arm_convolve_HWC_q7_fast_nonsquare.o arm_depthwise_separable_conv_HWC_q7_nonsquare.o arm_sub_q7.o arm_fully_connected_mat_q7_vec_q15_opt.o arm_mult_q7.o arm_nn_activations_q15.o arm_nn_activations_q7.o arm_relu_q15.o arm_nntables.o  nnom_upsample.o nnom_avgpool.o nnom_softmax.o nnom_flatten.o nnom_baselayer.o nnom_matrix.o nnom_maxpool.o nnom_cropping.o nnom_rnn.o nnom_output.o nnom_concat.o nnom_input.o nnom_lstm_cell.o nnom_gru_cell.o nnom_zero_padding.o nnom_lambda.o nnom_activation.o nnom_dw_conv2d.o nnom_simple_cell.o nnom_dense.o nnom_global_pool.o nnom_conv2d_trans.o nnom_conv2d.o nnom_sumpool.o nnom.o nnom_utils.o nnom_tensor.o nnom_layers.o nnom_local.o nnom_local_q15.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/main.c -o obj/main.o
# ./src/main.c:399:119: warning: multi-line // comment [-Wcomment]
#   ...&label, &prob);  // this provide more info but requires prediction API\
#                                                                            ^
# ./src/main.c:152:10: warning: unused variable 'input' [-Wunused-variable]
#         int8_t* input;
#                 ^
# ./src/main.c:132:9: warning: unused variable 'fc_layer_out' [-Wunused-variable]
#     int fc_layer_out = 96;
#         ^
# ./src/main.c:147:14: warning: unused variable 'index' [-Wunused-variable]
#     uint32_t index = 0;
#              ^
# ./src/main.c:155:9: warning: unused variable 'size' [-Wunused-variable]
#         size_t size = 0;
#                ^
# 5 warnings generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/image.c -o obj/image.o
# In file included from ./src/image.c:47:
# src/stb_image.h:6361:84: warning: unused parameter 'req_comp'
#       [-Wunused-parameter]
#   ...*s, stbi__gif *g, int *comp, int req_comp, stbi_uc *two_back)
#                                       ^
# src/stb_image.h:6585:107: warning: unused parameter 'ri' [-Wunused-parameter]
#   ...*s, int *x, int *y, int *comp, int req_comp, stbi__result_info *ri)
#                                                                      ^
# 2 warnings generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/args.c -o obj/args.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/matrix.c -o obj/matrix.o
# ./src/matrix.c:341:61: warning: comparison of integers of different signs:
#       'unsigned long' and 'int' [-Wsign-compare]
#      assert(fread(m.data, sizeof(float), m.rows*m.cols, fp) == m.rows*m.cols);
#             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^  ~~~~~~~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/assert.h:93:25: note:
#       expanded from macro 'assert'
#     (__builtin_expect(!(e), 0) ? __assert_rtn(__func__, __FILE__, __LINE...
#                         ^
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/data.c -o obj/data.o
# ./src/data.c:112:55: warning: format specifies type 'int' but the argument has
#       type 'size_t' (aka 'unsigned long') [-Wformat]
#                 fprintf(stderr, "malloc failed %d\n", size);
#                                                ~~     ^~~~
#                                                %zu
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/classifier.c -o obj/classifier.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/net.c -o obj/net.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c ./src/activation_layer.c -o obj/activation_layer.o
# ./src/activation_layer.c:98:36: warning: unused parameter 'l'
#       [-Wunused-parameter]
# void update_activation_layer(layer l, float rate, float momentum, float decay){}
#                                    ^
# ./src/activation_layer.c:98:45: warning: unused parameter 'rate'
#       [-Wunused-parameter]
# void update_activation_layer(layer l, float rate, float momentum, float decay){}
#                                             ^
# ./src/activation_layer.c:98:57: warning: unused parameter 'momentum'
#       [-Wunused-parameter]
# void update_activation_layer(layer l, float rate, float momentum, float decay){}
#                                                         ^
# ./src/activation_layer.c:98:73: warning: unused parameter 'decay'
#       [-Wunused-parameter]
# void update_activation_layer(layer l, float rate, float momentum, float decay){}
#                                                                         ^
# 4 warnings generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/FullyConnectedFunctions/arm_fully_connected_q7_opt.c -o obj/arm_fully_connected_q7_opt.o
# /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/FullyConnectedFunctions/arm_fully_connected_q7_opt.c:136:46: warning:
#       unused parameter 'vec_buffer' [-Wunused-parameter]
#                                       q15_t *vec_buffer)
#                                              ^
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_HWC_q7_basic.c -o obj/arm_convolve_HWC_q7_basic.o
# /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_HWC_q7_basic.c:87:45: warning:
#       unused parameter 'bufferA' [-Wunused-parameter]
#                                      q15_t *bufferA,
#                                             ^
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_HWC_q7_fast.c -o obj/arm_convolve_HWC_q7_fast.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ActivationFunctions/arm_relu_q7.c -o obj/arm_relu_q7.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/PoolingFunctions/arm_pool_q7_HWC.c -o obj/arm_pool_q7_HWC.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_HWC_q7_RGB.c -o obj/arm_convolve_HWC_q7_RGB.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/SoftmaxFunctions/arm_softmax_q7.c -o obj/arm_softmax_q7.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Source/StatisticsFunctions/arm_max_q7.c -o obj/arm_max_q7.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Source/BasicMathFunctions/arm_add_q7.c -o obj/arm_add_q7.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_1x1_HWC_q7_fast_nonsquare.c -o obj/arm_convolve_1x1_HWC_q7_fast_nonsquare.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_HWC_q15_fast.c -o obj/arm_convolve_HWC_q15_fast.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_HWC_q15_fast_nonsquare.c -o obj/arm_convolve_HWC_q15_fast_nonsquare.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_HWC_q7_basic_nonsquare.c -o obj/arm_convolve_HWC_q7_basic_nonsquare.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_convolve_HWC_q7_fast_nonsquare.c -o obj/arm_convolve_HWC_q7_fast_nonsquare.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ConvolutionFunctions/arm_depthwise_separable_conv_HWC_q7_nonsquare.c -o obj/arm_depthwise_separable_conv_HWC_q7_nonsquare.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Source/BasicMathFunctions/arm_sub_q7.c -o obj/arm_sub_q7.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/FullyConnectedFunctions/arm_fully_connected_mat_q7_vec_q15_opt.c -o obj/arm_fully_connected_mat_q7_vec_q15_opt.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Source/BasicMathFunctions/arm_mult_q7.c -o obj/arm_mult_q7.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ActivationFunctions/arm_nn_activations_q15.c -o obj/arm_nn_activations_q15.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ActivationFunctions/arm_nn_activations_q7.c -o obj/arm_nn_activations_q7.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/ActivationFunctions/arm_relu_q15.c -o obj/arm_relu_q15.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Source/NNSupportFunctions/arm_nntables.c -o obj/arm_nntables.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_upsample.c -o obj/nnom_upsample.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_avgpool.c -o obj/nnom_avgpool.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_softmax.c -o obj/nnom_softmax.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_flatten.c -o obj/nnom_flatten.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_flatten.c:77:41: warning:
#       unused parameter 'layer' [-Wunused-parameter]
# nnom_status_t flatten_run(nnom_layer_t *layer)
#                                         ^
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_baselayer.c -o obj/nnom_baselayer.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_matrix.c -o obj/nnom_matrix.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_matrix.c:166:20: warning:
#       comparison of integers of different signs: 'int' and 'size_t'
#       (aka 'unsigned long') [-Wsign-compare]
#                 for(int i = 0; i < num_input; i++)
#                                ~ ^ ~~~~~~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_matrix.c:199:20: warning:
#       comparison of integers of different signs: 'int' and 'size_t'
#       (aka 'unsigned long') [-Wsign-compare]
#                 for(int i = 0; i < num_input; i++)
#                                ~ ^ ~~~~~~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_matrix.c:231:20: warning:
#       comparison of integers of different signs: 'int' and 'size_t'
#       (aka 'unsigned long') [-Wsign-compare]
#                 for(int i = 0; i < num_input; i++)
#                                ~ ^ ~~~~~~~~~
# 3 warnings generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_maxpool.c -o obj/nnom_maxpool.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_cropping.c -o obj/nnom_cropping.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_rnn.c -o obj/nnom_rnn.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_output.c -o obj/nnom_output.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_concat.c -o obj/nnom_concat.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_concat.c:95:25: warning:
#       comparison of integers of different signs: 'uint32_t' (aka 'unsigned int')
#       and 'int32_t' (aka 'int') [-Wsign-compare]
#         for (uint32_t i = 0; i < num_dim; i ++)
#                              ~ ^ ~~~~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_concat.c:98:9: warning:
#       comparison of integers of different signs: 'uint32_t' (aka 'unsigned int')
#       and 'int8_t' (aka 'signed char') [-Wsign-compare]
#                 if (i == cl->axis)
#                     ~ ^  ~~~~~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_concat.c:204:20: warning:
#       comparison of integers of different signs: 'int' and 'uint32_t'
#       (aka 'unsigned int') [-Wsign-compare]
#         for (int i = 0; i < n_block; i++)
#                         ~ ^ ~~~~~~~
# 3 warnings generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_input.c -o obj/nnom_input.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_lstm_cell.c -o obj/nnom_lstm_cell.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_lstm_cell.c:57:47: warning:
#       unused parameter 'cell' [-Wunused-parameter]
# nnom_status_t lstm_cell_free(nnom_rnn_cell_t* cell)
#                                               ^
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_gru_cell.c -o obj/nnom_gru_cell.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_gru_cell.c:53:46: warning:
#       unused parameter 'cell' [-Wunused-parameter]
# nnom_status_t gru_cell_free(nnom_rnn_cell_t* cell)
#                                              ^
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_zero_padding.c -o obj/nnom_zero_padding.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_lambda.c -o obj/nnom_lambda.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_activation.c -o obj/nnom_activation.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_dw_conv2d.c -o obj/nnom_dw_conv2d.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_simple_cell.c -o obj/nnom_simple_cell.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_simple_cell.c:57:49: warning:
#       unused parameter 'cell' [-Wunused-parameter]
# nnom_status_t simple_cell_free(nnom_rnn_cell_t* cell)
#                                                 ^
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_dense.c -o obj/nnom_dense.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_global_pool.c -o obj/nnom_global_pool.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_conv2d_trans.c -o obj/nnom_conv2d_trans.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_conv2d_trans.c:52:135: warning:
#       unused parameter 'dilation' [-Wunused-parameter]
#   ...nnom_padding_t padding, uint32_t stride_size, uint32_t dilation)
#                                                             ^
# 1 warning generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_conv2d.c -o obj/nnom_conv2d.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/layers/nnom_sumpool.c -o obj/nnom_sumpool.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom.c -o obj/nnom.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom.c:108:17: warning:
#       unused function 'find_index' [-Wunused-function]
# static uint32_t find_index(nnom_layer_t *start, nnom_layer_t *layer)
#                 ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom.c:486:22: warning:
#       unused function 'layer_shortcut_find_last' [-Wunused-function]
# static nnom_layer_t *layer_shortcut_find_last(nnom_layer_t *start)
#                      ^
# 2 warnings generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom_utils.c -o obj/nnom_utils.o
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom_utils.c:185:20: warning:
#       comparison of integers of different signs: 'int' and 'uint32_t'
#       (aka 'unsigned int') [-Wsign-compare]
#         for (int i = 0; i < pre->label_num; i++)
#                         ~ ^ ~~~~~~~~~~~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom_utils.c:192:20: warning:
#       comparison of integers of different signs: 'int' and 'uint32_t'
#       (aka 'unsigned int') [-Wsign-compare]
#         for (int i = 0; i < pre->label_num; i++)
#                         ~ ^ ~~~~~~~~~~~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom_utils.c:197:21: warning:
#       comparison of integers of different signs: 'int' and 'uint32_t'
#       (aka 'unsigned int') [-Wsign-compare]
#                 for (int j = 0; j < pre->label_num; j++)
#                                 ~ ^ ~~~~~~~~~~~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom_utils.c:215:20: warning:
#       comparison of integers of different signs: 'int' and 'uint32_t'
#       (aka 'unsigned int') [-Wsign-compare]
#         for (int i = 0; i < pre->top_k_size; i++)
#                         ~ ^ ~~~~~~~~~~~~~~~
# 4 warnings generated.
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom_tensor.c -o obj/nnom_tensor.o
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -c /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/core/nnom_layers.c -o obj/nnom_layers.o
# ...
#                ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:291:9: warning:
#       unused parameter 'Im_out' [-Wunused-parameter]
#         q15_t *Im_out)
#                ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:360:17: warning:
#       unused parameter 'dim_im_out_x' [-Wunused-parameter]
#         const uint16_t dim_im_out_x, // output image dimension x or W
#                        ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:361:17: warning:
#       unused parameter 'dim_im_out_y' [-Wunused-parameter]
#         const uint16_t dim_im_out_y, // output image dimension y or H
#                        ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:362:8: warning:
#       unused parameter 'bufferA' [-Wunused-parameter]
#         q7_t *bufferA,               // a buffer for local storage, NULL by now
#               ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:394:8: warning:
#       unused parameter 'bufferA' [-Wunused-parameter]
#         q7_t *bufferA,               // a buffer for local storage, NULL by now
#               ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:441:9: warning:
#       unused parameter 'bufferA' [-Wunused-parameter]
#         q15_t *bufferA...
#                ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:442:8: warning:
#       unused parameter 'bufferB' [-Wunused-parameter]
#         q7_t *buffer...
#               ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:518:9: warning:
#       unused parameter 'bufferA' [-Wunused-parameter]
#         q15_t *bufferA...
#                ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:519:8: warning:
#       unused parameter 'bufferB' [-Wunused-parameter]
#         q7_t *buffer...
#               ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:616:20: warning:
#       unused parameter 'dilation_x' [-Wunused-parameter]
#     const uint16_t dilation_x,                                         /...
#                    ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:617:17: warning:
#       unused parameter 'dilation_y' [-Wunused-parameter]
#         const uint16_t dilation_y...
#                        ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:622:9: warning:
#       unused parameter 'bufferA' [-Wunused-parameter]
#         q15_t *bufferA...
#                ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:623:8: warning:
#       unused parameter 'bufferB' [-Wunused-parameter]
#         q7_t *buffer...
#               ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:745:9: warning:
#       unused parameter 'bufferA' [-Wunused-parameter]
#         q15_t *bufferA...
#                ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:746:8: warning:
#       unused parameter 'bufferB' [-Wunused-parameter]
#         q7_t *buffer...
#               ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:817:9: warning:
#       unused parameter 'bufferA' [-Wunused-parameter]
#         q15_t *bufferA...
#                ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:818:8: warning:
#       unused parameter 'bufferB' [-Wunused-parameter]
#         q7_t *buffer...
#               ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:879:17: warning:
#       unused parameter 'dim_im_out_y' [-Wunused-parameter]
#         const uint16_t dim_im_out_y)   // output image dimension y
#                        ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:954:17: warning:
#       unused parameter 'dim_im_in_y' [-Wunused-parameter]
#         const uint16_t dim_im_in_y,    // input image dimention y
#                        ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:957:17: warning:
#       unused parameter 'padding_bottom' [-Wunused-parameter]
#         const uint16_t padding_bottom, // padding sizes y
#                        ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:990:17: warning:
#       unused parameter 'padding_bottom' [-Wunused-parameter]
#         const uint16_t padding_bottom, // padding sizes y
#                        ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:992:17: warning:
#       unused parameter 'padding_right' [-Wunused-parameter]
#         const uint16_t padding_right,  // padding sizes x
#                        ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:1244:44: warning:
#       unused parameter 'vec_buffer' [-Wunused-parameter]
#                                    q15_t * vec_buffer)
#                                            ^
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:1344:16: warning:
#       comparison of integers of different signs: 'int' and 'uint32_t'
#       (aka 'unsigned int') [-Wsign-compare]
#         for(int i=0; i<size; i++)
#                      ~^~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:1371:17: warning:
#       comparison of integers of different signs: 'int' and 'uint32_t'
#       (aka 'unsigned int') [-Wsign-compare]
#                 for(int i=0; i<size; i++)
#                              ~^~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:1384:17: warning:
#       comparison of integers of different signs: 'int' and 'uint32_t'
#       (aka 'unsigned int') [-Wsign-compare]
#                 for(int i=0; i<size; i++)
#                              ~^~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:1585:19: warning:
#       comparison of integers of different signs: 'int' and 'unsigned int'
#       [-Wsign-compare]
#     for(int i=0; i<size/8; i++)
#                  ~^~~~~~~
# /Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/src/backends/nnom_local_q15.c:1596:19: warning:
#       comparison of integers of different signs: 'int' and 'unsigned int'
#       [-Wsign-compare]
#     for(int i=0; i<size%8; i++)
#                  ~^~~~~~~
# 33 warnings generated.
# gcc -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 -shared obj/main.o obj/image.o obj/args.o obj/matrix.o obj/list.o obj/data.o obj/classifier.o obj/net.o obj/convolutional_layer.o obj/connected_layer.o obj/activations.o obj/activation_layer.o obj/arm_fully_connected_q7_opt.o obj/arm_convolve_HWC_q7_basic.o obj/arm_convolve_HWC_q7_fast.o obj/arm_relu_q7.o obj/arm_pool_q7_HWC.o obj/arm_convolve_HWC_q7_RGB.o obj/arm_softmax_q7.o obj/arm_max_q7.o obj/arm_add_q7.o obj/arm_convolve_1x1_HWC_q7_fast_nonsquare.o obj/arm_convolve_HWC_q15_fast.o obj/arm_convolve_HWC_q15_fast_nonsquare.o obj/arm_convolve_HWC_q7_basic_nonsquare.o obj/arm_convolve_HWC_q7_fast_nonsquare.o obj/arm_depthwise_separable_conv_HWC_q7_nonsquare.o obj/arm_sub_q7.o obj/arm_fully_connected_mat_q7_vec_q15_opt.o obj/arm_mult_q7.o obj/arm_nn_activations_q15.o obj/arm_nn_activations_q7.o obj/arm_relu_q15.o obj/arm_nntables.o obj/nnom_upsample.o obj/nnom_avgpool.o obj/nnom_softmax.o obj/nnom_flatten.o obj/nnom_baselayer.o obj/nnom_matrix.o obj/nnom_maxpool.o obj/nnom_cropping.o obj/nnom_rnn.o obj/nnom_output.o obj/nnom_concat.o obj/nnom_input.o obj/nnom_lstm_cell.o obj/nnom_gru_cell.o obj/nnom_zero_padding.o obj/nnom_lambda.o obj/nnom_activation.o obj/nnom_dw_conv2d.o obj/nnom_simple_cell.o obj/nnom_dense.o obj/nnom_global_pool.o obj/nnom_conv2d_trans.o obj/nnom_conv2d.o obj/nnom_sumpool.o obj/nnom.o obj/nnom_utils.o obj/nnom_tensor.o obj/nnom_layers.o obj/nnom_local.o obj/nnom_local_q15.o -o libuwnet.so -lm -pthread
# ar rcs libuwnet.a obj/main.o obj/image.o obj/args.o obj/matrix.o obj/list.o obj/data.o obj/classifier.o obj/net.o obj/convolutional_layer.o obj/connected_layer.o obj/activations.o obj/activation_layer.o obj/arm_fully_connected_q7_opt.o obj/arm_convolve_HWC_q7_basic.o obj/arm_convolve_HWC_q7_fast.o obj/arm_relu_q7.o obj/arm_pool_q7_HWC.o obj/arm_convolve_HWC_q7_RGB.o obj/arm_softmax_q7.o obj/arm_max_q7.o obj/arm_add_q7.o obj/arm_convolve_1x1_HWC_q7_fast_nonsquare.o obj/arm_convolve_HWC_q15_fast.o obj/arm_convolve_HWC_q15_fast_nonsquare.o obj/arm_convolve_HWC_q7_basic_nonsquare.o obj/arm_convolve_HWC_q7_fast_nonsquare.o obj/arm_depthwise_separable_conv_HWC_q7_nonsquare.o obj/arm_sub_q7.o obj/arm_fully_connected_mat_q7_vec_q15_opt.o obj/arm_mult_q7.o obj/arm_nn_activations_q15.o obj/arm_nn_activations_q7.o obj/arm_relu_q15.o obj/arm_nntables.o obj/nnom_upsample.o obj/nnom_avgpool.o obj/nnom_softmax.o obj/nnom_flatten.o obj/nnom_baselayer.o obj/nnom_matrix.o obj/nnom_maxpool.o obj/nnom_cropping.o obj/nnom_rnn.o obj/nnom_output.o obj/nnom_concat.o obj/nnom_input.o obj/nnom_lstm_cell.o obj/nnom_gru_cell.o obj/nnom_zero_padding.o obj/nnom_lambda.o obj/nnom_activation.o obj/nnom_dw_conv2d.o obj/nnom_simple_cell.o obj/nnom_dense.o obj/nnom_global_pool.o obj/nnom_conv2d_trans.o obj/nnom_conv2d.o obj/nnom_sumpool.o obj/nnom.o obj/nnom_utils.o obj/nnom_tensor.o obj/nnom_layers.o obj/nnom_local.o obj/nnom_local_q15.o
# /Library/Developer/CommandLineTools/usr/bin/ranlib: file: libuwnet.a(activations.o) has no symbols
# gcc -Iinclude/ -Isrc/  -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/DSP/Include/ -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/Core/Include -I/Users/christosprofentzas/CMSIS-ML/CMSIS-updated/CMSIS_5/CMSIS/NN/Include -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/ -I/Users/christosprofentzas/CMSIS-ML/nrf52840/00microTL/fed_prunningNNOM-keyspot/inc/  -Wall -Wextra -Wno-unknown-pragmas -Wshift-overflow -ggdb3 -fPIC -O2 obj/main.o obj/image.o obj/args.o obj/matrix.o obj/list.o obj/data.o obj/classifier.o obj/net.o obj/convolutional_layer.o obj/connected_layer.o obj/activations.o obj/activation_layer.o obj/arm_fully_connected_q7_opt.o obj/arm_convolve_HWC_q7_basic.o obj/arm_convolve_HWC_q7_fast.o obj/arm_relu_q7.o obj/arm_pool_q7_HWC.o obj/arm_convolve_HWC_q7_RGB.o obj/arm_softmax_q7.o obj/arm_max_q7.o obj/arm_add_q7.o obj/arm_convolve_1x1_HWC_q7_fast_nonsquare.o obj/arm_convolve_HWC_q15_fast.o obj/arm_convolve_HWC_q15_fast_nonsquare.o obj/arm_convolve_HWC_q7_basic_nonsquare.o obj/arm_convolve_HWC_q7_fast_nonsquare.o obj/arm_depthwise_separable_conv_HWC_q7_nonsquare.o obj/arm_sub_q7.o obj/arm_fully_connected_mat_q7_vec_q15_opt.o obj/arm_mult_q7.o obj/arm_nn_activations_q15.o obj/arm_nn_activations_q7.o obj/arm_relu_q15.o obj/arm_nntables.o obj/nnom_upsample.o obj/nnom_avgpool.o obj/nnom_softmax.o obj/nnom_flatten.o obj/nnom_baselayer.o obj/nnom_matrix.o obj/nnom_maxpool.o obj/nnom_cropping.o obj/nnom_rnn.o obj/nnom_output.o obj/nnom_concat.o obj/nnom_input.o obj/nnom_lstm_cell.o obj/nnom_gru_cell.o obj/nnom_zero_padding.o obj/nnom_lambda.o obj/nnom_activation.o obj/nnom_dw_conv2d.o obj/nnom_simple_cell.o obj/nnom_dense.o obj/nnom_global_pool.o obj/nnom_conv2d_trans.o obj/nnom_conv2d.o obj/nnom_sumpool.o obj/nnom.o obj/nnom_utils.o obj/nnom_tensor.o obj/nnom_layers.o obj/nnom_local.o obj/nnom_local_q15.o -o uwnet -lm -pthread
# make: Leaving directory '/Users/christosprofentzas/CMSIS-ML/nrf52840/nnom/examples/keyword_spotting/fed_prunningNNOM-keyspot'
# ============================================================
# Tranfers Learning on low-power IoT devices
# Chalmers University
# ============================================================
# Model version: 0.4.3
# NNoM version 0.4.3
# To disable logs, please void the marco 'NNOM_LOG(...)' in 'nnom_port.h'.
# Data format: Channel last (HWC)
# Backend optimization: CMSIS-NN
# Start compiling model...
# Layer(#)         Activation    output shape    ops(MAC)   mem(in, out, buf)      mem blk lifetime
# -------------------------------------------------------------------------------------------------
# #1   Input      -          - (  62,  12,   1,)          (   744,   744,     0)    1 - - -  - - - -
# #2   Conv2D     - ReLU     - (  58,   8,  16,)     185k (   744,  7424,   100)    1 1 1 -  - - - -
# #3   MaxPool    -          - (  29,   8,  16,)          (  7424,  3712,     0)    1 1 1 -  - - - -
# #4   Conv2D     - ReLU     - (  27,   6,  32,)     746k (  3712,  5184,   576)    1 1 1 -  - - - -
# #5   MaxPool    -          - (  13,   6,  32,)          (  5184,  2496,     0)    1 1 1 -  - - - -
# #6   Conv2D     - ReLU     - (  11,   4,  64,)     811k (  2496,  2816,  1152)    1 1 1 -  - - - -
# #7   Conv2D     - ReLU     - (   9,   2,  32,)     331k (  2816,   576,  2304)    1 1 1 -  - - - -
# #8   Flatten    -          - ( 576,          )          (   576,   576,     0)    - 1 - -  - - - -
# #9   Dense      -          - (  35,          )      20k (   576,    35,  1152)    1 1 1 -  - - - -
# #10  Softmax    -          - (  35,          )          (    35,    35,     0)    1 - 1 -  - - - -
# #11  Output     -          - (  35,          )          (    35,    35,     0)    1 - - -  - - - -
# -------------------------------------------------------------------------------------------------
# Memory cost by each block:
#  blk_0:2304  blk_1:3712  blk_2:7424  blk_3:0  blk_4:0  blk_5:0  blk_6:0  blk_7:0
#  Memory cost by network buffers: 13440 bytes
#  Total memory occupied: 17128 bytes
# CNN last layer output size 2816
# label 32, yHat = 1.000000
# CNN OUT size 2816
#
# 1 :: train acc = 0.527500 &
# 2 :: train acc = 0.630000 &
# 3 :: train acc = 0.670000 &
# 4 :: train acc = 0.700000 &
# 5 :: train acc = 0.715000 &
# 6 :: train acc = 0.740000 &
# 7 :: train acc = 0.747500 &
#
# -----------------------------------------------------------------------------
# 1 :: train acc = 0.450000 & test acc = 0.463979
# 2 :: train acc = 0.602500 & test acc = 0.581475
# 3 :: train acc = 0.637500 & test acc = 0.633791
# 4 :: train acc = 0.652500 & test acc = 0.659520
# 5 :: train acc = 0.667500 & test acc = 0.678388
# 6 :: train acc = 0.680000 & test acc = 0.685249
# 7 :: train acc = 0.695000 & test acc = 0.698971
# 8 :: train acc = 0.712500 & test acc = 0.713551
# 9 :: train acc = 0.730000 & test acc = 0.719554
# 10 :: train acc = 0.742500 & test acc = 0.729846
# 11 :: train acc = 0.752500 & test acc = 0.741852
# 12 :: train acc = 0.765000 & test acc = 0.754717
# 13 :: train acc = 0.772500 & test acc = 0.758148
# 14 :: train acc = 0.782500 & test acc = 0.760720
# 15 :: train acc = 0.792500 & test acc = 0.769297
# 16 :: train acc = 0.797500 & test acc = 0.775300
# 17 :: train acc = 0.805000 & test acc = 0.778731
# 18 :: train acc = 0.810000 & test acc = 0.780446
# 19 :: train acc = 0.812500 & test acc = 0.787307
# 20 :: train acc = 0.812500 & test acc = 0.790738
# 21 :: train acc = 0.807500 & test acc = 0.794168
# 22 :: train acc = 0.807500 & test acc = 0.799314
# 23 :: train acc = 0.810000 & test acc = 0.801887
# 24 :: train acc = 0.815000 & test acc = 0.804460
# 25 :: train acc = 0.812500 & test acc = 0.806175
# 26 :: train acc = 0.820000 & test acc = 0.809605
# 27 :: train acc = 0.820000 & test acc = 0.809605
# 28 :: train acc = 0.827500 & test acc = 0.809605
# 29 :: train acc = 0.827500 & test acc = 0.809605
# 30 :: train acc = 0.835000 & test acc = 0.809605
# 31 :: train acc = 0.835000 & test acc = 0.811321
# 32 :: train acc = 0.835000 & test acc = 0.813894
# 33 :: train acc = 0.840000 & test acc = 0.817324
# 34 :: train acc = 0.845000 & test acc = 0.821612

# %%
# sumples = 100

# for i in range (30):
#     labelindices = np.random.choice(35, 3, replace=False)
#     print(labelindices)


#     sub_x_test = x_test[np.isin(y_test.flatten(), labelindices).flatten()]
#     sub_y_test = y_test[np.isin(y_test.flatten(), labelindices).flatten()] 
#     unique, counts = np.unique(sub_y_test[sumples], return_counts=True)
#     print(dict(zip(unique, counts)) )

#     generate_train_header(sub_x_test[:sumples], sub_y_test[:sumples], name='fed_prunningNNOM-keyspot/src/keyspot_train_data.h')
#     generate_test_bin(sub_x_test[sumples:], sub_y_test[sumples:], file='fed_prunningNNOM-keyspot/src/keyspot_test.h')
#     !make -C ./fed_prunningNNOM-keyspot/ 
#     !./fed_prunningNNOM-keyspot/uwnet

# %%
# !make -C ./fed_prunningNNOM-keyspot/

# %%
# generate_train_header(x_test[:sumples], y_test[:sumples], name='fed_prunningNNOM-keyspot/src/keyspot_train_data.h')
# generate_test_bin(x_test[sumples:], y_test[sumples:], file='fed_prunningNNOM-keyspot/src/keyspot_test.h')

# %%
# x_train = x_train[np.isin(y_train.flatten(), [0,1,2]).flatten()]
# y_train = y_train[np.isin(y_train.flatten(), [0,1,2]).flatten()]

# x_val = x_val[np.isin(y_val.flatten(), [0,1,2]).flatten()]
# y_val = y_val[np.isin(y_val.flatten(), [0,1,2]).flatten()]



# x_test = x_test[np.isin(y_test.flatten(), [0,1,2]).flatten()]
# y_test = y_test[np.isin(y_test.flatten(), [0,1,2]).flatten()] 

# y_test_original = y_test  # save for CI test


# y_train = one_hot(y_train, 3)
# y_test = one_hot(y_test,3)


# print("norm")
# print(x_train.shape)
# print(x_test.shape)
# # normolized each sensor, to range -1~1
# x_train = normalize(x_train)
# x_test  = normalize(x_test)

# generate binary test data, convert range to [-128 127] for mcu
# x_test_bin = np.clip(x_test *128, -128, 127)
# x_train_bin = np.clip(x_train*128, -128, 127)

# %%
len(x_val)

# %%
len(x_test)

# %%
# indices = np.random.choice(x_test.shape[0], 400, replace=False)
#     print(subset_x_train.shape[0])
# subset_x_train = x_train[indices]
# subset_y_train= y_train[indices]

# subset_x_test = x_test[indices]
# subset_y_test= y_train[indices]


# generate_train_header(x_test[:400], y_test[:400], name='har_train_data.h')

# generate_test_bin(x_test[400:], y_test[400:], file='har_test.h')




# generate_train_header(x_train_bin[:400], y_train[:400], name='00.bin')
# # generate_test_bin(x_train_bin[1750:1900], y_train[1750:1900], file='har_test.h')
# generate_test_bin(x_test_bin, y_test, file='har_test.h')

# %%
# !open .

# %%
import numpy as np

f = open("test_data.bin", "r")
a = np.fromfile(f, dtype=np.int8)

# %%
print (a[128:200])

# %%
# def generate_test_bin(x, y, name='test_data_with_label.bin'):
#     '''
#     this method generate the
#     :param x:  input x data size
#     :param y:  input label (one hot label)
#     :return:
#     '''
#     # quantize input x
#     min_value = np.min(x)
#     max_value = np.max(x)

#     int_bits = int(np.ceil(np.log2(max(abs(min_value), abs(max_value)))))
#     dec_bits = 7 - int_bits
#     x = np.round(x*2**dec_bits).astype(np.int8)
    
#     print(x[0][0])
#     data = x.astype(dtype="byte")
#     label = y
#     node = 0
#     file='har_test.h'
#     with open(file, 'w') as f:
#         num_of_image = x.shape[0]
#         for i in range(num_of_image):
#             f.write('#define NODE_%d_TRAIN_IMG_%d {'%(node,i) )
# #             print(data[i])
#             (data[i]).flatten().tofile(f, sep=", ") # convert 0~1 to 0~127
#             f.write('} \n')
#             f.write('#define NODE_%d_TRAIN_IMG%d_LABEL'% (node, i))
#             f.write(' %d \n \n' % label[i])
#         f.write('#define NODE_%d_TOTAL_TRAIN_IMAGES %d \n \n'%(node,num_of_image))

#         f.write('static q7_t NODE_%d_TRAIN_IMAGES[%d][%d] = {' % (node,num_of_image, data[0].flatten().shape[0]))
#         f.write('NODE_%d_TRAIN_IMG_0'%(node))
#         for i in range(num_of_image -1):
#             f.write(',NODE_%d_TRAIN_IMG_%d'%(node, i+1))
#         f.write('};\n\n')

#         f.write('static q7_t NODE_%d_TRAIN_LABELS[%d] = {' % (node,num_of_image))
#         f.write('NODE_%d_TRAIN_IMG0_LABEL'%(node))
#         for i in range(num_of_image -1):
#             f.write(',NODE_%d_TRAIN_IMG%d_LABEL'%(node, i+1))
#         f.write('};\n\n')

# #     return 000
