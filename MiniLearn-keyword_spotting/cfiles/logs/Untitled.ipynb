# %% [markdown]
# # CONV 1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42

MEDIUM_SIZE = 16
BIGGER_SIZE = 20

matplotlib.rc('font', size=BIGGER_SIZE)          # controls default text sizes
matplotlib.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('legend', fontsize=MEDIUM_SIZE)  

# torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.float32)/2**3)
# cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.float32)/2**3)

torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.int8))
torch_activation = np.float32(torch_activation) 
cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.int8))
cmsis_activation = np.float32(cmsis_activation) 
label = "Conv layer (float32)"
# plt.plot(torch_activation, label="PyTorch Original", c='r',linewidth=5, alpha=0.7)
plt.plot(cmsis_activation, label="CMSIS-NN Dequantized ", c='k',linewidth=3,linestyle='dashed')
plt.xlabel("Instances")
plt.ylabel("Weight Values")
plt.legend()
plt.tight_layout()
plt.savefig('Dequantize-Convolution-1.pdf') 
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42

MEDIUM_SIZE = 16
BIGGER_SIZE = 20

matplotlib.rc('font', size=BIGGER_SIZE)          # controls default text sizes
matplotlib.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('legend', fontsize=MEDIUM_SIZE)  

# torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.float32)/2**3)
# cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.float32)/2**3)

torch_activation = np.sort(np.fromfile("input.raw", dtype=np.int8))
torch_activation = np.float32(torch_activation)
label = "Conv layer (float32)"
plt.plot(torch_activation, label="PyTorch Original", c='r',linewidth=5, alpha=0.7)
# plt.plot(cmsis_activation, label="CMSIS-NN Dequantized ", c='k',linewidth=3,linestyle='dashed')
plt.xlabel("Instances")
plt.ylabel("Weight Values")
plt.legend()
plt.tight_layout()
plt.savefig('Dequantize-Convolution-1.pdf') 
plt.show()

# %% [markdown]
# # CONV 2

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42

MEDIUM_SIZE = 16
BIGGER_SIZE = 20

matplotlib.rc('font', size=BIGGER_SIZE)          # controls default text sizes
matplotlib.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('legend', fontsize=MEDIUM_SIZE)  



# torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.float32)/2**3)
# cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.float32)/2**3)

torch_activation = np.sort(np.fromfile("conv2_out_torch.raw", dtype=np.int8))
torch_activation = np.float32(torch_activation) 
cmsis_activation = np.sort(np.fromfile("conv2_out.raw", dtype=np.int8))
cmsis_activation = np.float32(cmsis_activation) 
label = "Conv layer (float32)"
# plt.plot(torch_activation, label="PyTorch Original", c='r',linewidth=5, alpha=0.7)
plt.plot(cmsis_activation, label="CMSIS-NN Dequantized ", c='k',linewidth=3,linestyle='dashed')
plt.xlabel("Instances")
plt.ylabel("Weight Values")
plt.legend()
plt.tight_layout()
plt.savefig('Dequantize-Convolution-2.pdf') 
plt.show()

# %% [markdown]
# # CONV 3

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42

MEDIUM_SIZE = 16
BIGGER_SIZE = 20

matplotlib.rc('font', size=BIGGER_SIZE)          # controls default text sizes
matplotlib.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('legend', fontsize=MEDIUM_SIZE)  

# torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.float32)/2**3)
# cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.float32)/2**3)

torch_activation = np.sort(np.fromfile("conv3_out_torch.raw", dtype=np.int8))
torch_activation = np.float32(torch_activation) / 2**2
cmsis_activation = np.sort(np.fromfile("conv3_out.raw", dtype=np.int8))
cmsis_activation = np.float32(cmsis_activation) /2**2
label = "Conv layer (float32)"
plt.plot(torch_activation, label="PyTorch Original", c='r',linewidth=5, alpha=0.7)
plt.plot(cmsis_activation, label="CMSIS-NN Dequantized ", c='k',linewidth=3,linestyle='dashed')

plt.xlabel("Instances")

plt.ylabel("Weight Values")
plt.legend()

plt.tight_layout()
plt.savefig('Dequantize-Convolution-3.pdf') 
plt.show()

# %% [markdown]
# # pool 1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42

MEDIUM_SIZE = 16
BIGGER_SIZE = 20

matplotlib.rc('font', size=BIGGER_SIZE)          # controls default text sizes
matplotlib.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('legend', fontsize=MEDIUM_SIZE)  



# torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.float32)/2**3)
# cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.float32)/2**3)

torch_activation = np.sort(np.fromfile("pool1_out_torch.raw", dtype=np.int8))
torch_activation = torch_activation / 2**7
cmsis_activation = np.sort(np.fromfile("pool1_out.raw", dtype=np.int8))
cmsis_activation = cmsis_activation /2**7
label = "Conv layer (float32)"
plt.plot(torch_activation, label="PyTorch Original", c='r',linewidth=5, alpha=0.7)
plt.plot(cmsis_activation, label="CMSIS-NN Dequantized ", c='k',linewidth=3,linestyle='dashed')
plt.xlabel("Matrix Instances")
plt.ylabel("Maxpool Values")
plt.legend()
plt.tight_layout()
plt.savefig('Dequantize-Pool-1.pdf') 
plt.show()

# %% [markdown]
# # Pool  2

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42

MEDIUM_SIZE = 16
BIGGER_SIZE = 20

matplotlib.rc('font', size=BIGGER_SIZE)          # controls default text sizes
matplotlib.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('legend', fontsize=MEDIUM_SIZE)  



# torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.float32)/2**3)
# cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.float32)/2**3)

torch_activation = np.sort(np.fromfile("pool2_out_torch.raw", dtype=np.int8))
torch_activation = torch_activation / 2**8
cmsis_activation = np.sort(np.fromfile("pool2_out.raw", dtype=np.int8))
cmsis_activation = cmsis_activation /2**8
label = "Conv layer (float32)"
plt.plot(torch_activation, label="PyTorch Original", c='r',linewidth=5, alpha=0.7)
plt.plot(cmsis_activation, label="CMSIS-NN Dequantized ", c='k',linewidth=3,linestyle='dashed')
plt.xlabel("Instances")

plt.ylabel("Weight Values")
plt.legend()

plt.tight_layout()
plt.savefig('Dequantize-Pool-2.pdf') 
plt.show()

# %% [markdown]
# # Pool 3

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42

MEDIUM_SIZE = 16
BIGGER_SIZE = 20

matplotlib.rc('font', size=BIGGER_SIZE)          # controls default text sizes
matplotlib.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('legend', fontsize=MEDIUM_SIZE)  



# torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.float32)/2**3)
# cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.float32)/2**3)

torch_activation = np.sort(np.fromfile("pool3_out_torch.raw", dtype=np.int8))
torch_activation = torch_activation / 2**7
cmsis_activation = np.sort(np.fromfile("pool3_out.raw", dtype=np.int8))
cmsis_activation = cmsis_activation /2**7
label = "Conv layer (float32)"
plt.plot(torch_activation, label="PyTorch Original", c='r',linewidth=5, alpha=0.7)
plt.plot(cmsis_activation, label="CMSIS-NN Dequantized ", c='k',linewidth=3,linestyle='dashed')
plt.xlabel("Instances")

plt.ylabel("Weight Values")
plt.legend()

plt.tight_layout()
plt.savefig('Dequantize-Pool-3.pdf') 
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42

MEDIUM_SIZE = 16
BIGGER_SIZE = 20

matplotlib.rc('font', size=BIGGER_SIZE)          # controls default text sizes
matplotlib.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
matplotlib.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
matplotlib.rc('legend', fontsize=MEDIUM_SIZE)  



# torch_activation = np.sort(np.fromfile("conv1_out_torch.raw", dtype=np.float32)/2**3)
# cmsis_activation = np.sort(np.fromfile("conv1_out.raw", dtype=np.float32)/2**3)

# torch_activation = np.sort(np.fromfile("y_out_torch.raw", dtype=np.int8))
# torch_activation = torch_activation / 2**4
cmsis_activation = np.sort(np.fromfile("y_out.raw", dtype=np.int8))
cmsis_activation = cmsis_activation /2**4
label = "Conv layer (float32)"
# plt.plot(torch_activation, label="PyTorch Original", c='r',linewidth=5, alpha=0.7)
plt.plot(cmsis_activation, label="CMSIS-NN Dequantized ", c='k',linewidth=3,linestyle='dashed')
plt.xlabel("Instances")

plt.ylabel("FC Output Values")
plt.legend()

plt.tight_layout()
plt.savefig('Dequantize-FC.pdf') 
plt.show()
